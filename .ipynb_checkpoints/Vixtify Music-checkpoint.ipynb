# %%
# !pip install spotipy --upgrade

# %%
client_id = '4a05ec0273d64243990bfee317f48246'
client_secret = '*********************'

# https://developer.spotify.com/dashboard/applications/4a05ec0273d64243990bfee317f48246/users

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

ClientCredentials = SpotifyClientCredentials( client_id = client_id, client_secret = client_secret ) 
sp = spotipy.Spotify( auth_manager = ClientCredentials )

results = sp.search(q='weezer', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Say It Ain't So
# 1 Island In The Sun
# 2 Undone - The Sweater Song
# 3 Buddy Holly
# 4 Beverly Hills
# 5 Africa
# 6 Hash Pipe
# 7 All My Favorite Songs (feat. AJR)
# 8 My Name Is Jonas
# 9 Enter Sandman
# 10 Pork And Beans
# 11 Lost in the Woods - Weezer Version
# 12 Take on Me
# 13 We Wish You A Merry Christmas
# 14 All My Favorite Songs
# 15 All My Favorite Songs
# 16 Pink Triangle
# 17 All My Favorite Songs
# 18 (If You're Wondering If I Want You To) I Want You To
# 19 El Scorcho

# %% [markdown]
# <iframe src="https://open.spotify.com/embed/album/0dL9rGQxUeIqpiUndXaQLl?utm_source=generator" width="100%" height="380" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %%
# https://www.programcreek.com/python/example/107939/spotipy.oauth2.SpotifyClientCredentials

# %%
# https://spotipy.readthedocs.io/en/2.16.1/

# %%
# https://github.com/plamere/spotipy

# %%
# # !pip install ShazamAPI

# from ShazamAPI import Shazam

# mp3_file_content_to_recognize = open('test.mp3', 'rb').read()  

# shazam = Shazam(mp3_file_content_to_recognize)
# recognize_generator = shazam.recognizeSong()

# while True:
#     print(next(recognize_generator)) # current offset & shazam response to recognize requests

# %%
# # !pip install shazamio
# https://github.com/imvickykumar999/ShazamIO

# import asyncio
# from shazamio import Shazam

# async def main():
#     shazam = Shazam()
#     track_id = 546891609
#     related = await shazam.related_tracks(track_id=track_id, limit=5, start_from=2)
#     # ONLY №3, №4 SONG
#     print(related) 

# loop = asyncio.get_event_loop()
# loop.run_until_complete(main())

# %%
# # !pip install nest-asyncio

# import nest_asyncio
# nest_asyncio.apply()
# __import__('IPython').embed()

# %%
# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials

ClientCredentials = SpotifyClientCredentials( client_id = client_id, client_secret = client_secret ) 
sp = spotipy.Spotify( auth_manager = ClientCredentials )

results = sp.search(q='despacito', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Despacito
# 1 Despacito - Remix
# 2 Despacito x Shape Of You
# 3 Despacito - Remix
# 4 Despacito
# 5 Despacito
# 6 Despacito 2
# 7 Despacito
# 8 Despacito
# 9 Despacito
# 10 Despacito
# 11 Despacito
# 12 Despacito (English Version)
# 13 Despacito
# 14 Despacito
# 15 Despacito
# 16 Despacito
# 17 Despacito - Versión Salsa
# 18 Despacito Too
# 19 Despacito - Remix

# %%
# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

results = sp.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Young Heart
# Beautiful Lies
# Beautiful Lies
# Beautiful Lies (Deluxe)
# Beautiful Lies (Deluxe)
# Fire Within
# Fire Within
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Live in London
# Birdy
# Birdy
# Birdy
# Birdy
# Birdy (Deluxe Version)

# %%
import spotipy
from pprint import pprint as p

urn = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'

artist = sp.artist(urn)
p(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#  'followers': {'href': None, 'total': 2531579},
#  'genres': ['alternative rock',
#             'modern power pop',
#             'modern rock',
#             'permanent wave',
#             'rock'],
#  'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#  'id': '3jOstUTkEu2JkjvRdBA5Gu',
#  'images': [{'height': 640,
#              'url': 'https://i.scdn.co/image/ab6761610000e5ebef2e09aeedd0d8f842d1a690',
#              'width': 640},
#             {'height': 320,
#              'url': 'https://i.scdn.co/image/ab67616100005174ef2e09aeedd0d8f842d1a690',
#              'width': 320},
#             {'height': 160,
#              'url': 'https://i.scdn.co/image/ab6761610000f178ef2e09aeedd0d8f842d1a690',
#              'width': 160}],
#  'name': 'Weezer',
#  'popularity': 76,
#  'type': 'artist',
#  'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}

# %%
user = sp.user('plamere')
p(user)
# Out:
# {'display_name': 'Paul Lamere',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/plamere'},
#  'followers': {'href': None, 'total': 284},
#  'href': 'https://api.spotify.com/v1/users/plamere',
#  'id': 'plamere',
#  'images': [{'height': None,
#              'url': 'https://scontent-nrt1-1.xx.fbcdn.net/v/t1.18169-1/p320x320/23755553_10155743258091091_7076319632011926032_n.jpg?_nc_cat=104&ccb=1-5&_nc_sid=0c64ff&_nc_ohc=sYL_E64yuX0AX9hiN-K&_nc_ht=scontent-nrt1-1.xx&edm=AP4hL3IEAAAA&oh=00_AT-5SJz3CuDdHem0KROIvCI5Y2_95gopS22cENLwEHZOag&oe=61EFC49D',
#              'width': None}],
#  'type': 'user',
#  'uri': 'spotify:user:plamere'}

# %%
# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

# sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
results = sp.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track     : ' + track['name'])
    print('audio     : ' + track['preview_url'])
    print('cover art : ' + track['album']['images'][0]['url'])
    print()
# Out:
# track     : Stairway to Heaven - Remaster
# audio     : https://p.scdn.co/mp3-preview/8226164717312bc411f8635580562d67e191a754?cid=4a05ec0273d64243990bfee317f48246
# cover art : https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track     : Immigrant Song - Remaster
# audio     : https://p.scdn.co/mp3-preview/8455599677a13017978dcd3f4b210937f0a16bcb?cid=4a05ec0273d64243990bfee317f48246
# cover art : https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track     : Whole Lotta Love - 1990 Remaster
# audio     : https://p.scdn.co/mp3-preview/ce11b19a4d2de9976d7626df0717d0073863909c?cid=4a05ec0273d64243990bfee317f48246
# cover art : https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track     : Black Dog - Remaster
# audio     : https://p.scdn.co/mp3-preview/9b76619fd9d563a48d38cc90ca00c3008327b52e?cid=4a05ec0273d64243990bfee317f48246
# cover art : https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# ...

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
val = list(results.values())
val
# Out:
# [[{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#     'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#     'id': '44Ig8dzqOkvkGDzaUof9lK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#       'width': 64}],
# ...

# %%
len(val)
# Out:
# 1

# %%
dv = val[0]
dv
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#    'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#    'id': '44Ig8dzqOkvkGDzaUof9lK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#      'width': 64}],
# ...

# %%
len(dv)
# Out:
# 10

# %%
data = dv[0]
data
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#   'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#   'id': '44Ig8dzqOkvkGDzaUof9lK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#     'width': 64}],
#   'name': 'Led Zeppelin IV (Deluxe Edition)',
# ...

# %%
type(data)
# Out:
# dict

# %%
k = list(data.keys())
k
# Out:
# ['album',
#  'artists',
#  'disc_number',
#  'duration_ms',
#  'explicit',
#  'external_ids',
#  'external_urls',
#  'href',
#  'id',
#  'is_local',
#  'is_playable',
#  'name',
#  'popularity',
#  'preview_url',
#  'track_number',
#  'type',
#  'uri']

# %%
v = list(data.values())
v
# Out:
# [{'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#   'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#   'id': '44Ig8dzqOkvkGDzaUof9lK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#     'width': 64}],
#   'name': 'Led Zeppelin IV (Deluxe Edition)',
# ...

# %%
len(v)
# Out:
# 17

# %%
dd = v[0]
dd
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#    'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#    'id': '36QJpDe2go2KgaRleHCDTp',
#    'name': 'Led Zeppelin',
#    'type': 'artist',
#    'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#  'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#  'id': '44Ig8dzqOkvkGDzaUof9lK',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#    'width': 64}],
#  'name': 'Led Zeppelin IV (Deluxe Edition)',
#  'release_date': '1971-11-08',
# ...

# %%
kk = dd.keys()
kk
# Out:
# dict_keys(['album_type', 'artists', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
vv = list(dd.values())
vv
# Out:
# ['album',
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#    'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#    'id': '36QJpDe2go2KgaRleHCDTp',
#    'name': 'Led Zeppelin',
#    'type': 'artist',
#    'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#  {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#  'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#  '44Ig8dzqOkvkGDzaUof9lK',
#  [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#    'width': 64}],
#  'Led Zeppelin IV (Deluxe Edition)',
#  '1971-11-08',
#  'day',
#  16,
#  'album',
#  'spotify:album:44Ig8dzqOkvkGDzaUof9lK']

# %%
len(vv)
# Out:
# 12

# %%
for i, j in enumerate(dd):
    print(i, '->', j)
    print(dd[j])
    print('.'*60, end='\n\n')
# Out:
# 0 -> album_type
# album
# ............................................................
#
# 1 -> artists
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}]
# ............................................................
#
# 2 -> external_urls
# {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'}
# ............................................................
#
# 3 -> href
# https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK
# ............................................................
#
# 4 -> id
# 44Ig8dzqOkvkGDzaUof9lK
# ............................................................
#
# 5 -> images
# ...

# %%
ClientCredentials = SpotifyClientCredentials( client_id = client_id, client_secret = client_secret ) 
sp = spotipy.Spotify( auth_manager = ClientCredentials )

results = sp.search(q='despacito', limit=3)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Despacito
# 1 Despacito - Remix
# 2 Despacito x Shape Of You

# %%
q = input('Enter song name : ')
results = sp.search(q=q, limit=20)

for i in results['tracks']['items']:
    if i['preview_url']:
        print(i['preview_url'])

# results
# Out:
# Enter song name : abcd
# https://p.scdn.co/mp3-preview/25a618c8bbf72ac750ab2024c8b987820ecc1cd1?cid=4a05ec0273d64243990bfee317f48246
# https://p.scdn.co/mp3-preview/f5a36a67019717fb6b66adb00051a12389f39ffc?cid=4a05ec0273d64243990bfee317f48246
# https://p.scdn.co/mp3-preview/68fcdf09e9c876ce7979e500ee4cefb9a6679d08?cid=4a05ec0273d64243990bfee317f48246
# https://p.scdn.co/mp3-preview/25a618c8bbf72ac750ab2024c8b987820ecc1cd1?cid=4a05ec0273d64243990bfee317f48246
# https://p.scdn.co/mp3-preview/34ca6d82b1d0813db653eee17a8021f37697ed16?cid=4a05ec0273d64243990bfee317f48246
# https://p.scdn.co/mp3-preview/baf1756e2efd5901f7554c167af7cb1b46b7cbf8?cid=4a05ec0273d64243990bfee317f48246
# https://p.scdn.co/mp3-preview/6965ab04527d9e766498f2746fb93107b18f8bb4?cid=4a05ec0273d64243990bfee317f48246
# https://p.scdn.co/mp3-preview/25a618c8bbf72ac750ab2024c8b987820ecc1cd1?cid=4a05ec0273d64243990bfee317f48246
# ...

# %%
len(results['tracks']['items'])
# Out:
# 3

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
lst = list(results['tracks']['items'][0].values())
len(lst)
# Out:
# 17

# %%
for i in lst:
    print(i, end='\n\n'+'.'*60+'\n')
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'}, 'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG', 'id': '4V8Sr092TqfHkfAA5fXXqG', 'name': 'Luis Fonsi', 'type': 'artist', 'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 
# ...

# %%
print(results['tracks']['items'][6]['preview_url'])
# Out:
# https://p.scdn.co/mp3-preview/87edcf25e1dca722628860c4cd058098f9397386?cid=4a05ec0273d64243990bfee317f48246

# %%
# !pip install spotipy --upgradepip install spotipy --upgrade

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = '4a05ec0273d64243990bfee317f48246'
client_secret = 'ff69fdebe3ea4e61a58f0f0497022c00'

ClientCredentials = SpotifyClientCredentials( client_id = client_id, client_secret = client_secret ) 
sp = spotipy.Spotify( auth_manager = ClientCredentials )

q = input('Enter song name : ')
results = sp.search(q=q, limit=20)
app = []

for i in results['tracks']['items']:
    if i['preview_url']:
        app.append(i['preview_url'])
        
print()
for i in app[:3]:
    print(i.split('/')[4].split('?')[0], '->', i)
# Out:
# Enter song name : abcd
#
# 25a618c8bbf72ac750ab2024c8b987820ecc1cd1 -> https://p.scdn.co/mp3-preview/25a618c8bbf72ac750ab2024c8b987820ecc1cd1?cid=4a05ec0273d64243990bfee317f48246
# f5a36a67019717fb6b66adb00051a12389f39ffc -> https://p.scdn.co/mp3-preview/f5a36a67019717fb6b66adb00051a12389f39ffc?cid=4a05ec0273d64243990bfee317f48246
# 68fcdf09e9c876ce7979e500ee4cefb9a6679d08 -> https://p.scdn.co/mp3-preview/68fcdf09e9c876ce7979e500ee4cefb9a6679d08?cid=4a05ec0273d64243990bfee317f48246

# %%
import IPython
IPython.display.Audio("25a618c8bbf72ac750ab2024c8b987820ecc1cd1.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
